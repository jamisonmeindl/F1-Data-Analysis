# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import joblib

# %%
model = joblib.load('model.pkl')

# %%
pred_data = pd.read_pickle('pred_data.pkl')

# %%
train_X = pd.read_pickle('train_X.pkl')

# %%
for col in train_X.columns:
    if col not in pred_data.columns:
        pred_data[col] = 0

# %%
X_cols = train_X.columns

# %%
pred_X = pred_data[X_cols]

# %%
pred_X = pred_X.fillna(pred_X.mean())

# %%
pred_X = (pred_X - train_X.mean()) / train_X.std()

# %%
pred_X
# Out:
#     LapPercent_1  LapPercent_2  PrevPosition1  PrevPosition2  PrevPosition3  \
# 0      -1.101327     -1.498121      -1.408979      -1.586427       0.895439
# 1      -0.619645     -0.256932       1.595205      -0.160042       0.008222
# 2      -0.218678     -0.978479      -1.232263       1.801237      -1.588768
# 3      -0.509423     -0.722378      -0.702112      -1.051532      -1.233881
# 4      -1.188117     -1.000795      -1.585696      -0.516638      -1.411324
# 5      -0.417426     -0.435459      -0.171962      -0.694936      -0.701551
# 6       0.695216      0.741971       0.888338       1.444641       1.782656
# 7       0.030408     -0.179357       1.418489       0.731449       0.540552
# 8       2.446629      0.625078       1.771922       0.909747       1.427769
# 9       0.304663      0.290340      -0.348679       0.374852       1.072882
# 10      0.073803     -0.312190       0.534905      -0.338340       1.250326
# 11      0.274287     -0.168731       1.065055       1.266343       0.363109
# 12     -0.369691      0.056554       1.241772       0.018256       0.185666
# 13     -0.239507     -0.428020       0.358188       0.196554      -0.524108
# 14      0.155385     -0.636302      -0.525396       0.553151       1.605212
# 15     -1.285321     -0.511970      -0.878829      -1.229830      -0.346664
# 16     -0.949446     -1.088996      -1.055546      -0.873234      -0.878994
# 17     -1.469315     -0.131537       0.181471      -1.408129      -1.056438
# 18      0.072935     -0.160229       0.711622       1.622939       0.717996
# 19     -0.006911     -0.000830       0.004755       1.088045      -0.169221
#
#     PrevLapPercent1  PrevLapPercent2  PrevLapPercent3
# 0         -1.246449        -1.393042        -0.985329
# 1          1.948038        -0.594358        -0.503311
# 2         -1.171992        -0.426763        -1.386471
# 3         -0.629316        -1.006980        -1.010400
# 4         -1.381044        -0.788812        -1.261114
# 5         -0.398070        -0.846674        -0.836518
# 6          0.078740         0.338072        31.161835
# 7          0.919960        -0.067910        -0.279286
# 8         -0.244861         0.127493         0.214054
# 9         -0.403081        -0.096367        -0.032616
# 10        -0.224815        -0.561159         0.011865
# 11         0.365113         0.321946        -0.419201
# 12         0.446013        -0.748024        -0.427288
# 13        -0.239133        -0.410338        -0.728954
# 14        -0.609270        -0.077395         0.378231
# 15        -0.683727        -1.040179        -0.611684
# 16        -0.798992        -0.882719        -0.847840
# 17        -0.342227        -1.169183        -0.907688
# 18         0.090911         0.486995        -0.251789
# 19        -0.373012         0.300130        -0.595509

# %%
pred_Y = model.predict(pred_X)

# %%
results = pd.DataFrame(data = {'DriverNumber': pred_data['DriverNumber'], 'Pred': pred_Y}).sort_values('Pred')
results['PredPosition'] = range(1, len(results) + 1)

# %%
results
# Out:
#    DriverNumber      Pred  PredPosition
# 4            16  0.004995             1
# 16           55  0.007387             2
# 3            14  0.009159             3
# 2            11  0.009424             4
# 0             1  0.009614             5
# 15           44  0.011147             6
# 17           63  0.011349             7
# 5            18  0.013647             8
# 13           31  0.016308             9
# 19           81  0.020752            10
# 1            10  0.020788            11
# 12           27  0.021895            12
# 14            4  0.022431            13
# 10           23  0.023011            14
# 11           24  0.024115            15
# 7            20  0.024279            16
# 18           77  0.024761            17
# 6             2  0.024906            18
# 9            22  0.025714            19
# 8            21  0.035622            20

# %%
pred_data[list(X_cols) + ['DriverNumber', 'Team', 'Driver', 'EventName']].sort_values('LapPosition_1')
# Out:
#     LapPosition_1  LapPosition_2  PrevPosition1  PrevPosition2  PrevPosition3  \
# 3               0              2            6.0            4.0            3.0
# 5               1             14            9.0            6.0            6.0
# 10              2              1           13.0            8.0           17.0
# 6               3             15           15.0           18.0           20.0
# 2               4              4            3.0           20.0            1.0
# 7               5              5           18.0           14.0           13.0
# 18              6              8           14.0           19.0           14.0
# 12              7             11           17.0           10.0           11.0
# 19              8              6           10.0           16.0            9.0
# 17              9              9           11.0            2.0            4.0
# 14             10             17            7.0           13.0           19.0
# 16             11             12            4.0            5.0            5.0
# 8              12             13           20.0           15.0           18.0
# 9              13             10            8.0           12.0           16.0
# 15             14             19            5.0            3.0            8.0
# 1              15             16           19.0            9.0           10.0
# 4              16              3            1.0            7.0            2.0
# 0              17              0            2.0            1.0           15.0
# 13             18             18           12.0           11.0            7.0
# 11             19              7           16.0           17.0           12.0
#
#    DriverNumber             Team Driver         EventName
# 3            14     Aston Martin    ALO  Miami Grand Prix
# 5            18     Aston Martin    STR  Miami Grand Prix
# 10           23         Williams    ALB  Miami Grand Prix
# 6             2         Williams    SAR  Miami Grand Prix
# 2            11  Red Bull Racing    PER  Miami Grand Prix
# 7            20     Haas F1 Team    MAG  Miami Grand Prix
# 18           77       Alfa Romeo    BOT  Miami Grand Prix
# 12           27     Haas F1 Team    HUL  Miami Grand Prix
# 19           81          McLaren    PIA  Miami Grand Prix
# 17           63         Mercedes    RUS  Miami Grand Prix
# 14            4          McLaren    NOR  Miami Grand Prix
# 16           55          Ferrari    SAI  Miami Grand Prix
# 8            21       AlphaTauri    DEV  Miami Grand Prix
# 9            22       AlphaTauri    TSU  Miami Grand Prix
# 15           44         Mercedes    HAM  Miami Grand Prix
# 1            10           Alpine    GAS  Miami Grand Prix
# 4            16          Ferrari    LEC  Miami Grand Prix
# 0             1  Red Bull Racing    VER  Miami Grand Prix
# 13           31           Alpine    OCO  Miami Grand Prix
# 11           24       Alfa Romeo    ZHO  Miami Grand Prix
