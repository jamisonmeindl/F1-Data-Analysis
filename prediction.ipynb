# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import joblib

# %%
model = joblib.load('model.pkl')

# %%
pred_data = pd.read_pickle('pred_data.pkl')

# %%
train_X = pd.read_pickle('train_X.pkl')

# %%
for col in train_X.columns:
    if col not in pred_data.columns:
        pred_data[col] = 0

# %%
X_cols = train_X.columns

# %%
pred_X = pred_data[X_cols]

# %%
pred_X = pred_X.fillna(pred_X.mean())

# %%
# pred_X = (pred_X - train_X.mean()) / train_X.std()

# %%
pred_X
# Out:
#     LapTimePercent_1  LapTimePercent_2  PrevLapTimePercent1  \
# 0           0.000000          0.000000             0.000000
# 1           0.013860          0.009208             0.012098
# 2           0.005056          0.002997             0.012207
# 3           0.007540          0.011989             0.008076
# 4           0.007675          0.010107             0.000745
# 5           0.009831          0.008947             0.007796
# 6           0.017201          0.007811             0.024180
# 7           0.020147          0.015452             0.024538
# 8           0.012314          0.016951             0.024584
# 9           0.016840          0.015952             0.021633
# 10          0.005519          0.002475             0.015468
# 11          0.019424          0.013023             0.022161
# 12          0.022472          0.009106             0.010856
# 13          0.008115          0.013216             0.016493
# 14          0.009492          0.013420             0.004147
# 15          0.013183          0.013681             0.006647
# 16          0.008544          0.000250             0.002951
# 17          0.014379          0.013170             0.016105
# 18          0.016817          0.014760             0.020018
# 19          0.011941          0.009628             0.018854
#
#     PrevLapTimePercent2  PrevLapTimePercent3  LapTimePrevPercentTeamAverage
# 0              0.004662             0.000000                              0
# 1              0.052855             0.007527                              0
# 2              0.028377             0.014694                              0
# 3              0.013350             0.011429                              0
# 4              0.024008             0.025003                              0
# 5              0.035046             0.009990                              0
# 6              0.058584             0.033581                              0
# 7              0.037510             0.024491                              0
# 8              0.056043             0.018112                              0
# 9              0.051077             0.022000                              0
# 10             0.000000             0.024781                              0
# 11             0.058647             0.017282                              0
# 12             0.020070             0.013242                              0
# 13             0.021353             0.010087                              0
# 14             0.007901             0.006974                              0
# 15             0.021607             0.007555                              0
# 16             0.014366             0.006393                              0
# 17             0.017440             0.014584                              0
# 18             0.039327             0.023591                              0
# 19             0.011864             0.010889                              0

# %%
pred_Y = model.predict(pred_X)

# %%
results = pd.DataFrame(data = {'DriverNumber': pred_data['DriverNumber'], 'Pred': pred_Y}).sort_values('Pred')
results['PredPosition'] = range(1, len(results) + 1)

# %%
results
# Out:
#    DriverNumber      Pred  PredPosition
# 0             1  0.000790             1
# 16           55  0.004431             2
# 2            11  0.007698             3
# 10           23  0.008169             4
# 14            4  0.008907             5
# 3            14  0.009450             6
# 5            18  0.009710             7
# 4            16  0.010387             8
# 15           44  0.010825             9
# 19           81  0.010847            10
# 13           31  0.011259            11
# 1            10  0.011686            12
# 12           27  0.012557            13
# 17           63  0.012968            14
# 18           77  0.016867            15
# 11           24  0.017116            16
# 8            21  0.017244            17
# 6             2  0.017572            18
# 9            22  0.017803            19
# 7            20  0.018424            20

# %%
pred_data['OfficialEventName']
# Out:
# 0     FORMULA 1 ARAMCO BRITISH GRAND PRIX 2023
# 1     FORMULA 1 ARAMCO BRITISH GRAND PRIX 2023
# 2     FORMULA 1 ARAMCO BRITISH GRAND PRIX 2023
# 3     FORMULA 1 ARAMCO BRITISH GRAND PRIX 2023
# 4     FORMULA 1 ARAMCO BRITISH GRAND PRIX 2023
# 5     FORMULA 1 ARAMCO BRITISH GRAND PRIX 2023
# 6     FORMULA 1 ARAMCO BRITISH GRAND PRIX 2023
# 7     FORMULA 1 ARAMCO BRITISH GRAND PRIX 2023
# 8     FORMULA 1 ARAMCO BRITISH GRAND PRIX 2023
# 9     FORMULA 1 ARAMCO BRITISH GRAND PRIX 2023
# 10    FORMULA 1 ARAMCO BRITISH GRAND PRIX 2023
# 11    FORMULA 1 ARAMCO BRITISH GRAND PRIX 2023
# 12    FORMULA 1 ARAMCO BRITISH GRAND PRIX 2023
# 13    FORMULA 1 ARAMCO BRITISH GRAND PRIX 2023
# 14    FORMULA 1 ARAMCO BRITISH GRAND PRIX 2023
# 15    FORMULA 1 ARAMCO BRITISH GRAND PRIX 2023
# 16    FORMULA 1 ARAMCO BRITISH GRAND PRIX 2023
# 17    FORMULA 1 ARAMCO BRITISH GRAND PRIX 2023
# 18    FORMULA 1 ARAMCO BRITISH GRAND PRIX 2023
# 19    FORMULA 1 ARAMCO BRITISH GRAND PRIX 2023
# Name: OfficialEventName, dtype: object
